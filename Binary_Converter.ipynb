# %%
import sys
def getInt(question):
        while True:
            if question=='exit':
                sys.exit()
            else:
                # if the entered argument is a number
                try:
                    q=int(question)
                    print("Number of Bits :")
                    bits=int(input())
                    binaryStr(int(question),bits)
                    print("Enter a positive Int")
                    question=input()
                    
                # when the entered argument is not a number then user will be prompted
                except ValueError:
                    print("Not a number.")
                    print("Enter a positive Int")
                    question=input()
                

        
def binaryStr(num,bits):
    if num<0:
        print("Number is negative. Cannot be converted.")
    else:
        
        s="" # variable to store number as binary
    
        # To convert number into binary
        while num!=0:
            s=str(num%2)+s
            num=num//2
        
        print("As Binary : ",end="")   
        if len(s)<bits:   #  padding with zero
            pre=""
            for i in range(bits-len(s)):
                pre=pre+"0"
            print(pre+s)
        
        elif len(s)>bits: # truncating the binary string obtained from left
            print(s[len(s)-bits:])
        else:
            print(s)

def main():
    print("Welcome to Binary Printer.")
    print("Enter exit to quit at any time.")
    print("Enter a positive Int :")
    ques=input()
    getInt(ques)

main()
# Out:
# Welcome to Binary Printer.
# Enter exit to quit at any time.
# Enter a positive Int :
# cats
# Not a number.
# Enter a positive Int
# 12
# Number of Bits :
# 3
# As Binary : 100
# Enter a positive Int
# 12
# Number of Bits :
# 8
# As Binary : 00001100
# Enter a positive Int
# 12
# Number of Bits :
# 8
# As Binary : 00001100
# Enter a positive Int
# 0
# Number of Bits :
# 4
# As Binary : 0000
# Enter a positive Int
# 0
# Number of Bits :
# 32
# As Binary : 00000000000000000000000000000000
# Enter a positive Int
# 900
# Number of Bits :
# 8
# As Binary : 10000100
# Enter a positive Int
# 900
# Number of Bits :
# 4
# As Binary : 0100
# Enter a positive Int
# 900
# Number of Bits :
# 12
# As Binary : 001110000100
# Enter a positive Int
# -6
# Number of Bits :
# 5
# Number is negative. Cannot be converted.
# Enter a positive Int
# exit
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# ...
